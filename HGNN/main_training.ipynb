# %%
import time as time_
start_t = time_.time()
# %run model.py

t = time_.time() - start_t
print(f'time taken: {(t/60):.2f} (mins)')
# Out:
# WARNING:tensorflow:From /storage/home/hcocice1/sshourie3/.local/lib/python3.8/site-packages/tensorflow/python/keras/layers/legacy_rnn/rnn_cell_impl.py:584: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /storage/home/hcocice1/sshourie3/.local/lib/python3.8/site-packages/tensorflow/python/keras/layers/legacy_rnn/rnn_cell_impl.py:594: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Number of parameters: 1207.0
# Optimizer used: Adam
# train_size is 8000
# train_batch is 500
# now batch: 0, total batch: 500
# now():2023-04-23 20:12:12.230939
# ...

# %%
# import time
# start_t = time.time()
t = time.time() - start_t
print(f'time taken: {(t/60):.2f} (mins)')

# %%
# pip install tensorflow
# %pip install tensorflow-gpu
# %pip install torch

# %%
import torch
torch.cuda.is_available()
# !nvidia-smi

# %%
# !python --version
# tf.test.is_gpu_available()
# import tensorflow as tf
tf.config.list_physical_devices('GPU')
# tf.test.is_built_with_cuda()
# tf.test.is_gpu_available()

# %%
import os
# os.listdir('sarora320')
# os.getcwd()
os.listdir('/storage/home/hcocice1/sarora320/wstm/NGNN/data/polyvore_image_vectors-001')

# %%
files = os.listdir('/storage/home/hcocice1/sarora320/wstm/NGNN/data/polyvore_image_vectors-001/polyvore_image_vectors-001/')
# files = os.listdir('../../../../sarora320/wstm/NGNN/data/polyvore_image_vectors-001/polyvore_image_vectors-001/')
# [x for x in files if x.startswith('179670628')]

# %%
# import time
# start_t = time.time()
x = time.time() - start_t
print(f'time taken: {x/60:.2f} (mins)')
